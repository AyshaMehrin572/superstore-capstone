# %%
import pandas as pd

df = pd.read_csv("../data/superstore_sales.csv")
df.head()
# Out:
#        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2018-1001  2018-01-05  2018-01-08    Second Class     CU-1001
# 1  CA-2018-1002  2018-01-07  2018-01-10  Standard Class     CU-1002
# 2  CA-2018-1003  2018-02-10  2018-02-12     First Class     CU-1003
# 3  CA-2018-1004  2018-02-15  2018-02-18    Second Class     CU-1004
# 4  CA-2018-1005  2018-03-01  2018-03-04  Standard Class     CU-1005
#
#        Segment   Region         Category Sub-Category  Sales  Profit  \
# 0     Consumer     East       Technology       Phones   1200     300
# 1    Corporate     West        Furniture       Chairs    450      50
# 2  Home Office  Central  Office Supplies        Paper     80      20
# 3     Consumer    South       Technology  Accessories    230      60
# 4    Corporate     East        Furniture       Tables    600     -40
#
#    Quantity  Discount
# 0         2       0.1
# 1         3       0.0
# 2         5       0.0
# 3         2       0.1
# 4         1       0.2

# %%
df.shape
# Out:
# (24, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      24 non-null     object
#  1   Order Date    24 non-null     object
#  2   Ship Date     24 non-null     object
#  3   Ship Mode     24 non-null     object
#  4   Customer ID   24 non-null     object
#  5   Segment       24 non-null     object
#  6   Region        24 non-null     object
#  7   Category      24 non-null     object
#  8   Sub-Category  24 non-null     object
#  9   Sales         24 non-null     int64
#  10  Profit        24 non-null     int64
#  11  Quantity      24 non-null     int64
#  12  Discount      24 non-null     float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 2.6+ KB

# %%
# Convert dates
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

# Remove duplicates
df.drop_duplicates(inplace=True)

# Check missing values
df.isnull().sum()
# Out:
# Order ID        0
# Order Date      0
# Ship Date       0
# Ship Mode       0
# Customer ID     0
# Segment         0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Profit          0
# Quantity        0
# Discount        0
# dtype: int64

# %%
# Create new features
df["Year"] = df["Order Date"].dt.year
df["Month"] = df["Order Date"].dt.month

# %%
total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()
average_order_value = df["Sales"].mean()

total_sales, total_profit, average_order_value
# Out:
# (np.int64(18410), np.int64(3375), np.float64(767.0833333333334))

# %%
monthly_sales = df.groupby("Month")["Sales"].sum()

plt.figure()
monthly_sales.plot()
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# Cell In[7], line 3
#       1 monthly_sales = df.groupby("Month")["Sales"].sum()
# ----> 3 plt.figure()
#       4 monthly_sales.plot()
#       5 plt.title("Monthly Sales Trend")
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
monthly_sales.plot()
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
category_sales = df.groupby("Category")["Sales"].sum()

plt.figure()
category_sales.plot(kind="bar")
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
## Key Business Insights

1. Technology category consistently outperforms other categories in both sales and profit.
2. Monthly sales trends show seasonal spikes, indicating high-demand periods.
3. Certain furniture sub-categories (like Tables) generate losses despite high sales volume, suggesting a need for pricing or cost optimization.
# Out:
#   Cell In[11], line 3
#     1. Technology category consistently outperforms other categories in both sales and profit.
#        ^
# SyntaxError: invalid syntax

# %%
## Key Business Insights

1. Technology category consistently outperforms other categories in both sales and profit.
2. Monthly sales trends show seasonal spikes, indicating high-demand periods.
3. Certain furniture sub-categories (like Tables) generate losses despite high sales volume, suggesting a need for pricing or cost optimization.
# Out:
#   Cell In[13], line 4
#     1. Technology category consistently outperforms other categories in both sales and profit.
#        ^
# SyntaxError: invalid syntax

# %%
M
## Key Business Insights
Technology category consistently outperforms other categories in both sales and profit.
Monthly sales trends show seasonal spikes, indicating high-demand periods.
Certain furniture sub-categories (like Tables) generate losses despite high sales volume, suggesting a need for pricing or cost optimization.
# Out:
#   Cell In[14], line 3
#     Technology category consistently outperforms other categories in both sales and profit.
#                ^
# SyntaxError: invalid syntax

# %%
M
## Conclusion

This analysis highlights key sales drivers and problem areas in the superstore business.
The insights can help decision-makers improve profitability and plan inventory and marketing strategies effectively.
# Out:
#   Cell In[15], line 4
#     This analysis highlights key sales drivers and problem areas in the superstore business.
#          ^
# SyntaxError: invalid syntax
